# %%
import json
import torch
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

BASE_DIR = r"D:\pycharm\Transformer"
DATA_DIR = os.path.join(BASE_DIR, "data", "Dataset")
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

os.makedirs(DATA_DIR, exist_ok=True)

print("数据目录:", DATA_DIR)
# Out:
# 数据目录: D:\pycharm\Transformer\data\Dataset

# %%
import zipfile

zip_path = os.path.join(DATA_DIR, "Dataset.zip")

metadata_path = os.path.join(DATA_DIR, "metadata.json")


if not os.path.exists(metadata_path):

    print("开始解压数据...")

    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall(DATA_DIR)

    print("数据解压完成！")

else:
    print("检测到数据已存在，跳过解压。")
# Out:
# 检测到数据已存在，跳过解压。

# %%
class SpeakerDataset(Dataset):

    def __init__(self, data_dir):


        with open(os.path.join(data_dir, "metadata.json"), "r") as f:
            metadata = json.load(f)

        self.data = []


        speakers = metadata["speakers"]


        self.speaker2id = {
            speaker: idx
            for idx, speaker in enumerate(speakers.keys())
        }


        for speaker, utts in speakers.items():


            for utt in utts:

                self.data.append({
                    "feature_path": utt["feature_path"],
                    "speaker_id": self.speaker2id[speaker]
                })

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):

        item = self.data[idx]

        feat_path = os.path.join(
            DATA_DIR,
            item["feature_path"]
        )

        feat = torch.load(feat_path)

        label = item["speaker_id"]

        return feat, label

# %%
def collate_fn(batch):
    feats, labels = zip(*batch)

    lengths = [f.shape[0] for f in feats]
    max_len = max(lengths)

    padded = []
    for f in feats:
        pad_len = max_len - f.shape[0]
        pad = torch.zeros(pad_len, f.shape[1])
        padded.append(torch.cat([f, pad], dim=0))

    return torch.stack(padded), torch.tensor(labels)

# %%
class EasyModel(nn.Module):

    def __init__(self):

        super().__init__()

        self.input_proj = nn.Linear(40, 128)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=128,
            nhead=4,
            dim_feedforward=256,
            dropout=0.1,
            batch_first=True
        )

        self.encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=2
        )

        self.pool = nn.AdaptiveAvgPool1d(1)

        self.fc = nn.Linear(128, 600)

    def forward(self, x):

        x = self.input_proj(x)

        x = self.encoder(x)

        x = x.transpose(1, 2)

        x = self.pool(x).squeeze(-1)

        return self.fc(x)

# %%
dataset = SpeakerDataset(DATA_DIR)

loader = DataLoader(
    dataset,
    batch_size=32,
    shuffle=True,
    collate_fn=collate_fn,
    num_workers=0
)

# %%
model = EasyModel().to(DEVICE)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=1e-3
)

EPOCHS = 15

# %%
for epoch in range(EPOCHS):

    model.train()

    total_loss = 0

    for x, y in tqdm(loader):

        x = x.to(DEVICE)
        y = y.to(DEVICE)

        pred = model(x)

        loss = criterion(pred, y)

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1}")
    print(f"Loss: {total_loss / len(loader):.4f}")
# Out:
#   0%|          | 6/2170 [00:02<15:44,  2.29it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 12
#       9 x = x.to(DEVICE)
#      10 y = y.to(DEVICE)
# ---> 12 pred = model(x)
#      14 loss = criterion(pred, y)
#      16 optimizer.zero_grad()
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# Cell In[6], line 30, in EasyModel.forward(self, x)
#      26 def forward(self, x):
#      28     x = self.input_proj(x)
# ---> 30     x = self.encoder(x)
#      32     x = x.transpose(1, 2)
#      34     x = self.pool(x).squeeze(-1)
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\transformer.py:538, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask, is_causal)
#     535 is_causal = _detect_is_causal_mask(mask, is_causal, seq_len)
#     537 for mod in self.layers:
# --> 538     output = mod(
#     539         output,
#     540         src_mask=mask,
#     541         is_causal=is_causal,
#     542         src_key_padding_mask=src_key_padding_mask_for_layers,
#     543     )
#     545 if convert_to_nested:
#     546     output = output.to_padded_tensor(0.0, src.size())
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\transformer.py:950, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, is_causal)
#     946     x = x + self._ff_block(self.norm2(x))
#     947 else:
#     948     x = self.norm1(
#     949         x
# --> 950         + self._sa_block(x, src_mask, src_key_padding_mask, is_causal=is_causal)
#     951     )
#     952     x = self.norm2(x + self._ff_block(x))
#     954 return x
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\transformer.py:964, in TransformerEncoderLayer._sa_block(self, x, attn_mask, key_padding_mask, is_causal)
#     957 def _sa_block(
#     958     self,
#     959     x: Tensor,
#    (...)
#     962     is_causal: bool = False,
#     963 ) -> Tensor:
# --> 964     x = self.self_attn(
#     965         x,
#     966         x,
#     967         x,
#     968         attn_mask=attn_mask,
#     969         key_padding_mask=key_padding_mask,
#     970         need_weights=False,
#     971         is_causal=is_causal,
#     972     )[0]
#     973     return self.dropout1(x)
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\modules\activation.py:1492, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1466     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1467         query,
#    1468         key,
#    (...)
#    1489         is_causal=is_causal,
#    1490     )
#    1491 else:
# -> 1492     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1493         query,
#    1494         key,
#    1495         value,
#    1496         self.embed_dim,
#    1497         self.num_heads,
#    1498         self.in_proj_weight,
#    1499         self.in_proj_bias,
#    1500         self.bias_k,
#    1501         self.bias_v,
#    1502         self.add_zero_attn,
#    1503         self.dropout,
#    1504         self.out_proj.weight,
#    1505         self.out_proj.bias,
#    1506         training=self.training,
#    1507         key_padding_mask=key_padding_mask,
#    1508         need_weights=need_weights,
#    1509         attn_mask=attn_mask,
#    1510         average_attn_weights=average_attn_weights,
#    1511         is_causal=is_causal,
#    1512     )
#    1513 if self.batch_first and is_batched:
#    1514     return attn_output.transpose(1, 0), attn_output_weights
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\functional.py:6510, in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v, average_attn_weights, is_causal)
#    6506     if in_proj_weight is None:
#    6507         raise AssertionError(
#    6508             "use_separate_proj_weight is False but in_proj_weight is None"
#    6509         )
# -> 6510     q, k, v = _in_projection_packed(query, key, value, in_proj_weight, in_proj_bias)
#    6511 else:
#    6512     if q_proj_weight is None:
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\nn\functional.py:5871, in _in_projection_packed(q, k, v, w, b)
#    5868 proj = linear(q, w, b)
#    5869 # reshape to 3, E and not E, 3 is deliberate for better memory coalescing and keeping same order as chunk()
#    5870 proj = (
# -> 5871     proj.unflatten(-1, (3, E))
#    5872     .unsqueeze(0)
#    5873     .transpose(0, -2)
#    5874     .squeeze(-2)
#    5875     .contiguous()
#    5876 )
#    5877 # pyrefly: ignore [bad-return]
#    5878 return proj[0], proj[1], proj[2]
#
# File D:\Anaconda\envs\ml\lib\site-packages\torch\_tensor.py:1456, in Tensor.unflatten(self, dim, sizes)
#    1454     return super().unflatten(dim, sizes, names)
#    1455 else:
# -> 1456     return super().unflatten(dim, sizes)
#
# KeyboardInterrupt:
